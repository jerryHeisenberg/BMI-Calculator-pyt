# %%
#PYTHON PROJECT


print("\t\t\t\t\t\t WELCOME")
print("/////////////////////////////////////////////////////////////////////////////////////////////////////////////////////")
print("---------------------------------------------------------------------------------------------------------------------")

def repeat():
    print("\t\t\t\t\t\tMAIN MENU")
    print("_____________________________________________________________________________________________________________________")
    print("*********************************************************************************************************************")
    print("To Calculate BMI: Press 1")
    print("To View Membership rates: Press 2")
    print("To Exit program: Press 3")
#BMI Calculator

    n=input("Select the following options: ")
    if n=='1':
        def repeat1():
            print("\t\t\t\t\tCALCULATE YOUR BODY MASS INDEX")
            print("For Standard: press \'s\'")
            print("For Metric: press \'m\'")
            print("Back to menu: press \'b\'")
            c=input("")
            if c=='s' or c=='standard':
        
                w1=float(input("Enter your weight in lbs: "))
                h1,h3=int(input("feet: ")),int(input("inches: "))
                print(w1 ,"lbs")
                print(h1,"'",h3,"ft")
        
                #Calculator
                lbs=w1/2.205
                f=h1*12
                f2=f+h3
                fts= f2 * 2.54
                x2=fts/100
                x3=x2*x2
                t1=lbs/x3
                float_b = float(t1)
                limit_f = round(float_b, 2)
  
                print(limit_f)
    
                if limit_f<18.5:
                    print("Underweight")
                elif limit_f>=18.5 and limit_f<=25:
                    print("Normal")
                elif limit_f>25 and limit_f<=30:
                    print("Overweight")
                elif limit_f>=30:
                    print("Obese")
                
                print("Do you want to perform another calculation?")
                z=input("'y'or 'n' & 'e' to exit program")
                if z=='y':
                    repeat1()
                
                elif z=='n':
                    repeat()
                elif z=='e':
                    print("\t\t\t\t\t\tThank you!")
                    print("\t\t\t\t\t  For using our program")
                    exit()
        
            elif c=='m' or c=='metric':
                w2=float(input("Enter your weight in kgs: "))
                h2=float(input("Enter your height in cm: "))
                print(w2 ,"kgs",h2,"cm")
        
                #Calculator
                x=h2/100
                x1=x*x
                t2=w2/x1
                float_a = float(t2)
                limit_f = round(float_a, 2)  
  
                print(limit_f)

                if limit_f<18.5:
                    print("Underweight")
                elif limit_f>=18.5 and limit_f<=25:
                    print("Normal")
                elif limit_f>25 and limit_f<=30:
                    print("Overweight")
                elif limit_f>=30:
                    print("Obese")
            
                print("Do you want to perform another calculation?")
                z=input("'y'or 'n' & 'e' to exit program")
                if z=='y':
                    repeat1()
                    
                elif z=='n':
                    repeat()
              
                elif z=='e':
                    print("\t\t\t\t\t\tThank you!")
                    print("\t\t\t\t\t  For using our program")
                    exit()
                     
            elif c=='b':
                repeat()
    
        
    
        repeat1()
#Membership Rates   
    elif n=='2':
        def repeat2():
            print("\t\t\t\t\t\tMembership Rates")
            print("Choose the options below")
            print("Enter 'basic'")
            print("Enter 'regular'")
            print("Enter 'premium'")
            print("Back to menu: press \'b\'")
            d=input("")
            
            if d=='basic':
                weekly=1000
                monthly=weekly*30
                print('Basic: Membership cost per week is Rs: ',weekly)
                print('Basic: Membership cost per month is Rs: ',monthly)
                
                print("Do you want to check other rates?")
                z=input("'y'or 'n' & 'e' to exit program")
                if z=='y':
                    repeat2()
                    
                elif z=='n':
                    repeat()
              
                elif z=='e':
                    print("\t\t\t\t\t\tThank you!")
                    print("\t\t\t\t\t  For using our program")
                    exit()
                
            elif d=='regular' or d=='reg':
                weekly=1500
                monthly=weekly*30
                print('Regular: Membership cost per week is Rs: ',weekly)
                print('Regular: Membership cost per month is Rs: ',monthly)
                
                print("Do you want to check other rates?")
                z=input("'y'or 'n' & 'e' to exit program")
                if z=='y':
                    repeat2()
                    
                elif z=='n':
                    repeat()
              
                elif z=='e':
                    print("\t\t\t\t\t\tThank you!")
                    print("\t\t\t\t\t  For using our program")
                    exit()
            elif d=='premium'or d=='pre':
                weekly=2000
                monthly=weekly*30
                print('Premium: Membership cost per week is Rs: ',weekly)
                print('Premium: Membership cost per month is Rs: ',monthly)
                
                print("Do you want to check other rates?")
                z=input("'y'or 'n' & 'e' to exit program")
                if z=='y':
                    repeat2()
                    
                elif z=='n':
                    repeat()
              
                elif z=='e':
                    print("\t\t\t\t\t\tThank you!")
                    print("\t\t\t\t\t  For using our program")
                    exit()
        
            elif d=='b':
                repeat()
                
                
                
        repeat2()
        
           
    elif n=='3':
        print("\t\t\t\t\t\tThank you!")
        print("\t\t\t\t\t  For using our program")
        exit()
            
        
repeat()

#fin..
# Out:
# 						 WELCOME
# /////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# ---------------------------------------------------------------------------------------------------------------------
# 						MAIN MENU
# _____________________________________________________________________________________________________________________
# *********************************************************************************************************************
# To Calculate BMI: Press 1
# To View Membership rates: Press 2
# To Exit program: Press 3
# Select the following options: 1
# 					CALCULATE YOUR BODY MASS INDEX
# For Standard: press 's'
# For Metric: press 'm'
# Back to menu: press 'b'
# m
# Enter your weight in kgs: 82
# Enter your height in cm: 178
# 82.0 kgs 178.0 cm
# 25.88
# Overweight
# Do you want to perform another calculation?
# ---------------------------------------------------------------------------
# ...
